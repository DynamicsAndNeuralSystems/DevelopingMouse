# %%
# shows detailed info about possible RMA query methods
from allensdk.api.queries.rma_api import RmaApi


rma = RmaApi()
# http://api.brain-map.org/api/v2/data.json
schema = rma.get_schema()
for entry in schema:
    data_description = entry['DataDescription']
    clz = data_description.keys()[0]
    info = data_description.values()[0]
    fields = info['fields']
    associations = info['associations']
    table = info['table']
    print("class: %s" % (clz))
    print("fields: %s" % (','.join(f['name'] for f in fields)))
    print("associations: %s" % (','.join(a['name'] for a in associations)))
    print("table: %s\n" % (table))
# Out:
# class: SubImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks
# table: sub_images
#
# class: SpecimenImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,specimen
# table: sub_images
#
# class: ProjectionImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,specimen
# table: sub_images
#
# class: BlockfaceImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,specimen
# table: sub_images
#
# class: MosaicImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,specimen
# table: sub_images
#
# class: SectionImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,section_data_set,treatments,alignment2d,annotation_infos,atlas_contours,polygon_spatial_mappings,shapes,associates
# table: sub_images
#
# class: MicroarrayPreImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,section_data_set,treatments,alignment2d,annotation_infos,atlas_contours,polygon_spatial_mappings,shapes,associates
# table: sub_images
#
# class: MicroarrayPostImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,section_data_set,treatments,alignment2d,annotation_infos,atlas_contours,polygon_spatial_mappings,shapes,associates
# table: sub_images
#
# class: AtlasImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,section_data_set,treatments,alignment2d,annotation_infos,atlas_contours,polygon_spatial_mappings,shapes,associates,atlas_data_set
# table: sub_images
#
# class: OphysExperimentImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,ophys_experiment
# table: sub_images
#
# class: IsiExperimentImage
# fields: id,type,path,x,y,width,height,section_number,failed,specimen_id,data_set_id,resolution,tier_count,expression_path,image_width,image_height,annotated,structure_id,image_type,lims1_id,bits_per_component,number_of_components,projection_function,axes,ophys_experiment_id,isi_experiment_id
# associations: structure,data_set,graphic_objects,alternate_images,sub_image_annotations,ish_canonical_blocks,isi_experiment
# table: sub_images
#
# class: AffymetrixTranscriptCluster
# fields: id,displayable_id_from_affymetrix
# associations: gene_association,genome_locus
# table: affymetrix_transcript_clusters
#
# class: OphysExperimentAnalysisRun
# fields: id,ophys_experiment_id,data
# associations: ophys_experiment
# table: ophys_experiment_analysis_runs
#
# class: NeuronalModelRun
# fields: id,name,explained_variance_ratio,rheobase_feature_average,neuronal_model_id,tags
# associations: neuronal_model,well_known_files
# table: neuronal_model_runs
#
# class: SubImageAnnotation
# fields: id,sub_image_id,description,width,height,x,y,zoom,abs_x,abs_y,weight,failed,sphinx_id,red_lower,red_upper,green_lower,green_upper,blue_lower,blue_upper,x_mid_point,y_mid_point,failed_facet
# associations: transgenic_line,sub_image,sub_image_annotation_tags
# table: sub_image_annotations
#
# class: EphysResult
# fields: id,failed,sampling_rate
# associations: specimens,well_known_files
# table: ephys_results
#
# class: ApiTbiDonorDetail
# fields: donor_id,name,age,sex,apo_e4_allele,education_years,age_at_first_tbi,longest_loc_duration,cerad,num_tbi_w_loc,dsm_iv_clinical_diagnosis,control_set,nincds_arda_diagnosis,ever_tbi_w_loc,race,hispanic,act_demented,braak,nia_reagan
# associations: donor
# table: api_tbi_donor_details
#
# class: TumorFeature
# fields: id,structure_id,data_set_id,sum_pixels,area,normalized_area,nuclei_count,nuclei_coverage_faction
# associations: data_set,structure
# table: tumor_features
#
# class: CellPrepSample
# fields: id,cell_prep_roi
# associations: cells,specimens
# table: cell_prep_samples
#
# class: Probe
# fields: id,name,label,orientation_id,gene_id,predicted_sequence_id,forward_sequence_id,reverse_sequence_id,ncbi_accession_number,gi,probe_type,fluor_color,gc_percent,sphinx_id,delegate
# associations: gene,gene_association,orientation,predicted_sequence,forward_primer_sequence,reverse_primer_sequence,microarray_designs,data_sets,products
# table: probes
#
# class: Reference3dSpace
# fields: id,name,grayscale_volume_path,annotation_volume_path,x_max,y_max,z_max,um_per_pixel,version,superseded_by_id,organism_id,ontology_id,created_at,updated_at,published_at
# associations: organism,ontology,superseded_by
# table: reference3d_spaces
#
# class: HeatmapRun
# fields: id,name,heatmap_columns_file_id,heatmap_rows_file_id,heatmap_matrix_file_id,heatmap_normalized_zip_file_id
# associations: heatmap_columns_file,heatmap_rows_file,heatmap_matrix_file,heatmap_normalized_zip_file
# table: heatmap_runs
#
# class: TransgenicLine
# fields: id,name,stock_number,transgenic_line_type_name,transgenic_line_type_code,transgenic_line_source_name,originating_lab,url_prefix,url_suffix,description,sub_image_annotation_id
# associations: sub_image_annotation,donors,transgenic_mice,genes
# table: transgenic_lines
#
# class: Transcript
# fields: id,gene_id,molbio_authority_id,ncbi_accession_number,agilent_upload
# associations: gene,molbio_authority
# table: transcripts
#
# class: DataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features
# table: data_sets
#
# class: RnaseqExonDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features
# table: data_sets
#
# class: SectionDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,structure_unionizes,projection_structure_unionizes,fine_structure_searches,alignment3d,equalization,annotation_infos,polygon_spatial_mappings
# table: data_sets
#
# class: AtlasDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,structure_unionizes,projection_structure_unionizes,fine_structure_searches,alignment3d,equalization,annotation_infos,polygon_spatial_mappings,atlas_images,atlases
# table: data_sets
#
# class: ExonMicroarrayGeneDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features
# table: data_sets
#
# class: ExonMicroarrayExonDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features
# table: data_sets
#
# class: CellImageDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,alignment3d
# table: data_sets
#
# class: RnaseqGeneDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,rnaseq_design
# table: data_sets
#
# class: TissueSampleDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,samples
# table: data_sets
#
# class: MicroarrayDataSet
# fields: id,name,type,specimen_id,plane_of_section_id,failed,section_thickness,qc_date,expression,storage_directory,reference_space_id,weight,sphinx_id,rnaseq_design_id,red_channel,green_channel,blue_channel,delegate,failed_facet
# associations: specimen,plane_of_section,reference_space,manual_annotations,section_images,sub_images,well_known_files,treatments,probes,genes,products,differential_expression_rankings,tumor_features,samples,microarray_slides,graphic_objects
# table: data_sets
#
# class: ApiGbmRnaSeqSamplesDetail
# fields: donor_id,tumor_name,molecular_subtype,extent_of_resection,surgery,mgmt_methylation,survival_days,egfr_amplification,initial_kps,age_in_years,tumor_id,sub_block_id,sub_block_name,study_name,specimen_page_link,sample_id,structure_id,structure_acronym,structure_name,structure_parent_id,structure_parent_acronym,structure_parent_name
# associations: donor,specimen,sample,sub_block,structure_parent
# table: api_gbm_rna_seq_samples_details
#
# class: GeneClassification
# fields: id,name,source,category,use
# associations: genes,gene_classification_counts
# table: gene_classifications
#
# class: GraphicObject
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Shape
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Circle
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Rect
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Path
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Polygon
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Polyline
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Line
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Ellipse
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: TextContent
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Text
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets
# table: graphic_objects
#
# class: Group
# fields: id,type,order,parent_id,address,graphic_group_label_id,sub_image_id,structure_id,path,mag,display_attributes,template_id
# associations: graphic_transformations,graphic_objects,clones,parent,template,sub_image,structure,graphic_group_label,groups,polygon_spatial_mappings,microarray_data_sets,atlas_contours
# table: graphic_objects
#
# class: Well
# fields: id,donor_id
# associations: donor
# table: wells
#
# class: CellRoiAnalysisRun
# fields: id,cell_roi_id,data
# associations: cell_roi
# table: cell_roi_analysis_runs
#
# class: Structure
# fields: id,atlas_id,name,acronym,st_level,ontology_id,hemisphere_id,weight,parent_structure_id,depth,graph_id,graph_order,structure_id_path,color_hex_triplet,neuro_name_structure_id,neuro_name_structure_id_path,failed,sphinx_id,structure_name_facet,failed_facet,safe_name
# associations: parent,children,ancestor_hierarchies,self_and_ancestors,descendant_hierarchies,self_and_descendants,structure_graph,ontology,hemisphere,neuro_name_structure,specimens,structure_sets_structures,structure_sets,structure_centers,parent_structure,child_structures,graph,annotation_infos,atlas_contours,data_points,fine_structure_searches,injections,manual_annotations,ontology_nodes,polygon_spatial_mappings,samples,shapes,structure_bounding_boxes,atlases,structure_unionizes,projection_structure_unionizes,sub_images,differential_expression_rankings,tumor_features,annotation_structures,hotspot_specimens,stereotaxic_injections
# table: structures
#
# class: StructureHierarchy
# fields: ancestor_id,descendant_id,generations
# associations: ancestor,descendant
# table: structure_hierarchies
#
# class: StructureSetsStructure
# fields: structure_set_id,structure_id,id,structure_order
# associations: structure,structure_set
# table: structure_sets_structures
#
# class: StructureLookup
# fields: id,term,termtype,structure_id,ontology_id
# associations: structure,ontology
# table: structure_lookups
#
# class: ReferenceToReferenceTransform
# fields: id,from_reference_space_id,to_reference_space_id,t_00,t_01,t_02,t_03,t_04,t_05,t_06,t_07,t_08,t_09,t_10,t_11
# associations: from_reference_space,to_reference_space
# table: reference_to_reference_transforms
#
# class: AnnotationInfo
# fields: id,atlas_id,section_data_set_id,section_image_id,structure_id,specimen_tissue_index,x,y,w,h,max_zoom,filepath,order,path
# associations: atlas,section_data_set,section_image,structure
# table: annotation_infos
#
# class: Injection
# fields: id,specimen_id,injection_quality,days_post_injection,targeted_injection_structure_id,injection_method,primary_injection_structure_id,injection_materials,fluor_colors,structure_id,age_id,coordinates_ap,coordinates_ml,coordinates_dv,angle,registration_point
# associations: specimen,structure,age,primary_injection_structure,targeted_injection_structure
# table: injections
#
# class: HomologousGeneAssociation
# fields: id,gene_id,homologous_gene_id,source
# associations: homologous_gene,gene
# table: homologous_gene_associations
#
# class: Gene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: AffymetrixGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: NcbiGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: TigrGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: AgilentGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: RikenGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: ErccGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: EnsemblGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs,genome_locuses
# table: genes
#
# class: FusionGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: UniGene
# fields: id,name,entrez_id,acronym,organism_id,chromosome_id,homologene_id,type,legacy_ensembl_gene_id,ensembl_id,alias_tags,sphinx_id,original_symbol,original_name,version_status,genomic_reference_update_id,reference_genome_id
# associations: organism,transcripts,gene_classifications,chromosome,genomic_reference_update,reference_genome,gene_aliases,probes,gene_lookups,gene_classification_counts,products,data_sets,gene_associations,transgenic_lines,molbio_authority,data_points,homologous_gene_associations,homologous_genes,ensembl_genes,ncbi_genes,rnaseq_designs
# table: genes
#
# class: RnaseqProfile
# fields: id,total_reads,percent_reads_aligned_to_mrna,percent_reads_aligned_to_ncrna,percent_reads_aligned_to_genome_only,sample_id,reference_genome_id
# associations: sample,reference_genome,well_known_files
# table: rnaseq_profiles
#
# class: AlternateImage
# fields: id,sub_image_id,path,image_type
# associations: sub_image
# table: alternate_images
#
# class: ApiCamStimulusMapping
# fields: id,stimulus_name,item,level,item_type
# associations:
# table: api_cam_stimulus_mappings
#
# class: GeneAssociationSource
# fields: id,name,description
# associations: gene_associations
# table: gene_association_sources
#
# class: Atlas
# fields: id,name,structure_graph_id,specimen_id,xyz_sort,treatment_id,reference_space_id,description,image_type
# associations: structure_graph,specimen,treatment,graphic_group_labels,reference_space,atlas_data_sets,annotation_infos,atlas_contours,atlas_infos,ish_canonical_blocks
# table: atlases
#
# class: Sequence
# fields: id,sequence_data,sequence_length
# associations: probes_with_predicted_sequences,probe_with_forward_primer_sequences,probes_with_reverse_primer_sequences
# table: sequences
#
# class: StereotaxicInjectionMaterial
# fields: id,name,fluor_colors
# associations: stereotaxic_injections
# table: stereotaxic_injection_materials
#
# class: PlaneOfSection
# fields: id,name,plane_of_section_name_facet
# associations: atlas_infos,data_sets
# table: plane_of_sections
#
# class: ApiCamCellMetric
# fields: cell_specimen_id,experiment_container_id,specimen_id,area,tld1_id,tld1_name,tld2_id,tld2_name,tlr1_id,tlr1_name,imaging_depth,failed_experiment_container,drifting_grating_large,drifting_grating_small,natural_movie_one_a_large,natural_movie_one_a_small,natural_movie_three_large,natural_movie_three_small,speed_tuning_a_large,speed_tuning_a_small,natural_movie_one_b_large,natural_movie_one_b_small,natural_scene_large,natural_scene_small,speed_tuning_b_large,speed_tuning_b_small,locally_sparse_noise_off_large,locally_sparse_noise_off_small,locally_sparse_noise_on_large,locally_sparse_noise_on_small,natural_movie_one_c_large,natural_movie_one_c_small,natural_movie_two_large,natural_movie_two_small,speed_tuning_c_large,speed_tuning_c_small,static_gratings_large,static_gratings_small,osi_dg,dsi_dg,pref_dir_dg,pref_tf_dg,p_dg,osi_sg,pref_ori_sg,pref_sf_sg,pref_phase_sg,p_sg,time_to_peak_sg,pref_image_ns,time_to_peak_ns,p_ns,all_stim,donor_full_genotype,g_dsi_dg,g_osi_dg,g_osi_sg,image_sel_ns,p_run_mod_dg,p_run_mod_ns,p_run_mod_sg,peak_dff_dg,peak_dff_ns,peak_dff_sg,receptive_field_off_large,receptive_field_off_small,receptive_field_on_large,receptive_field_on_small,reliability_dg,reliability_nm1_a,reliability_nm1_b,reliability_nm1_c,reliability_nm2,reliability_nm3,reliability_ns,reliability_sg,rf_area_off_lsn,rf_area_on_lsn,rf_center_off_x_lsn,rf_center_off_y_lsn,rf_center_on_x_lsn,rf_center_on_y_lsn,rf_chi2_lsn,rf_distance_lsn,rf_overlap_index_lsn,run_mod_dg,run_mod_ns,run_mod_sg,sfdi_sg,signal_correlation_a_large,signal_correlation_a_small,signal_correlation_b_large,signal_correlation_b_small,tfdi_dg
# associations:
# table: api_cam_cell_metrics
#
# class: GoExon
# fields: id
# associations: genome_locus,gene_association
# table: go_exons
#
# class: ApiColumnDefinition
# fields: api_class_name,internal_name,description,treatment_id,full_name,gene_id,method,display_name,long_display_name
# associations:
# table: api_column_definitions
#
# class: GenomicReferenceUpdate
# fields: id,name,update_date,previous_update_id,description
# associations: reference_genomes,genes,previous_update
# table: genomic_reference_updates
#
# class: Treatment
# fields: id,name,tags,treatment_name_facet
# associations: atlases,atlas_infos,data_sets,specimens
# table: treatments
#
# class: Age
# fields: id,name,description,days,embryonic,organism_id,tags,age_group_id
# associations: developmental_stages,organism,age_group,atlas_infos,donors,injections,stereotaxic_injections,reference_spaces,differential_expression_rankings
# table: ages
#
# class: MicroarrayDesign
# fields: id,name
# associations: microarray_slides,probes
# table: microarray_designs
#
# class: GenomicObject
# fields: id,name,type,seqid,source,feature,start,stop,score,strand,phase,organism_id,genomic_reference_update_id,gene_symbol,entrez_id,chromosome_id,full_accession,gene_aliases,homologene_id,version_status,reference_genome_id
# associations: genomic_reference_update,reference_genome,organism,chromosome
# table: genomic_objects
#
# class: GenomicObjectTranscript
# fields: id,name,type,seqid,source,feature,start,stop,score,strand,phase,organism_id,genomic_reference_update_id,gene_symbol,entrez_id,chromosome_id,full_accession,gene_aliases,homologene_id,version_status,reference_genome_id
# associations: genomic_reference_update,reference_genome,organism,chromosome
# table: genomic_objects
#
# class: GenomicObjectGene
# fields: id,name,type,seqid,source,feature,start,stop,score,strand,phase,organism_id,genomic_reference_update_id,gene_symbol,entrez_id,chromosome_id,full_accession,gene_aliases,homologene_id,version_status,reference_genome_id
# associations: genomic_reference_update,reference_genome,organism,chromosome
# table: genomic_objects
#
# class: GenomicObjectExon
# fields: id,name,type,seqid,source,feature,start,stop,score,strand,phase,organism_id,genomic_reference_update_id,gene_symbol,entrez_id,chromosome_id,full_accession,gene_aliases,homologene_id,version_status,reference_genome_id
# associations: genomic_reference_update,reference_genome,organism,chromosome
# table: genomic_objects
#
# class: TransgenicMouse
# fields: id,name,transgenic_induction_method_name,transgenic_induction_method_description
# associations: donors,transgenic_lines
# table: transgenic_mice
#
# class: MolbioAuthority
# fields: id,name,description,gene_type_class
# associations: transcripts,genes,gene_associations
# table: molbio_authorities
#
# class: OphysExperiment
# fields: id,name,specimen_id,targeted_structure_id,stimulus_name,imaging_depth,experiment_container_id,storage_directory,date_of_acquisition,fail_eye_tracking
# associations: specimen,targeted_structure,experiment_container,ophys_experiment_images,ophys_experiment_analysis_runs,well_known_files
# table: ophys_experiments
#
# class: MicroarraySlide
# fields: id,barcode,microarray_design_id,sample_id,rna_in_array,rna_in_labeling_reaction
# associations: microarray_design,microarray_data_sets,structures,sample,well_known_files
# table: microarray_slides
#
# class: PolygonSpatialMapping
# fields: id,specimen_id,section_data_set_id,section_image_id,graphic_group_label_id,graphic_object_id,structure_id,section_number,section_image_cx,section_image_cy,cx,cy,mri_cx,mri_cy,mri_cz
# associations: specimen,section_data_set,section_image,graphic_group_label,graphic_object,structure
# table: polygon_spatial_mappings
#
# class: ApiCellMetadata
# fields: rnaseq_profile_id,donor_id,donor_age,genotype_driver,genotype_reporter,cell_reporter,cell_prep_sample_id,sampling_region,slice_index,slice_id,slice_name,cell_id,rnaseq_profile_total_reads,rnaseq_profile_percent_reads_aligned_to_mrna,rnaseq_profile_percent_reads_aligned_to_ncrna,rnaseq_profile_percent_reads_aligned_to_genome_only,subclass,broad_class_color,subclass_order,broad_class,subclass_color,broad_class_order
# associations: rnaseq_profile,donor,cell_prep_sample,slice,cell
# table: api_cell_metadata
#
# class: EtlRecord
# fields: id,name,average_run_time,number_of_runs,run_frequency,run_order
# associations: warehouse_tables
# table: etl_records
#
# class: ProjectionStructureUnionize
# fields: id,section_data_set_id,structure_id,hemisphere_id,is_injection,sum_pixels,sum_projection_pixels,sum_pixel_intensity,sum_projection_pixel_intensity,projection_density,projection_intensity,projection_energy,volume,projection_volume,normalized_projection_volume,max_voxel_density,max_voxel_x,max_voxel_y,max_voxel_z
# associations: section_data_set,structure,hemisphere
# table: projection_structure_unionizes
#
# class: OntologyNode
# fields: id,depth,st_order,structure_id_path,acronym_path,color,acronym,name,structure_graph_id,structure_id
# associations: structure_graph,structure
# table: ontology_nodes
#
# class: StructureSet
# fields: id,name,description
# associations: structure_sets_structures,structures
# table: structure_sets
#
# class: EphysFeature
# fields: id,specimen_id,rheobase_sweep_id,thumbnail_sweep_id,vrest,ri,sag,vm_for_sag,tau,upstroke_downstroke_ratio_ramp,upstroke_downstroke_ratio_short_square,upstroke_downstroke_ratio_long_square,peak_v_ramp,peak_t_ramp,peak_v_short_square,peak_t_short_square,peak_v_long_square,peak_t_long_square,trough_v_ramp,trough_t_ramp,trough_v_short_square,trough_t_short_square,trough_v_long_square,trough_t_long_square,fast_trough_v_ramp,fast_trough_t_ramp,fast_trough_v_short_square,fast_trough_t_short_square,fast_trough_v_long_square,fast_trough_t_long_square,slow_trough_v_ramp,slow_trough_t_ramp,slow_trough_v_short_square,slow_trough_t_short_square,slow_trough_v_long_square,slow_trough_t_long_square,threshold_v_ramp,threshold_v_short_square,threshold_v_long_square,threshold_i_ramp,threshold_i_short_square,threshold_i_long_square,threshold_t_ramp,threshold_t_short_square,threshold_t_long_square,adaptation,latency,avg_isi,f_i_curve_slope,has_burst,has_pause,has_delay,seal_gohm,input_resistance_mohm,electrode_0_pa,rheobase_sweep_number
# associations: specimen,rheobase_sweep,thumbnail_sweep
# table: ephys_features
#
# class: SpecimenType
# fields: id,name,specimen_type_name_facet
# associations: ish_canonical_blocks,specimens
# table: specimen_types
#
# class: DifferentialExpressionRanking
# fields: id,data_set_id,age_id,structure_id,differential_expression_rankings_type,expression_energy,rank
# associations: data_set,age,structure
# table: differential_expression_rankings
#
# class: RnaseqDesign
# fields: id,name
# associations: rnaseq_gene_data_sets,genes
# table: rnaseq_designs
#
# class: Donor
# fields: id,name,age_id,organism_id,strain,sex,transgenic_mouse_id,handedness,pmi,condition_description,external_donor_name,sex_full_name,tags,multifocal,recurrence_by_six_months,sleep_state,smoker,theiler_stage,race_only,strain_only,donor_sex_facet,donor_strain_facet,donor_strain_only_facet,donor_race_only_facet,donor_condition_description_facet,primary_tissue_source,chemotherapy,egfr_amplification,extent_of_resection,mgmt_methylation,pten_deletion,radiation_therapy,tumor_status,initial_kps,time_to_progression_or_recurrence,weight_grams,mgmt_ihc,survival_days,molecular_subtype,data,date_of_birth,full_genotype
# associations: age,organism,transgenic_mouse,well_known_files,transgenic_lines,specimens,donor_condition_values,conditions,products,data_points,disease_categories,medical_conditions
# table: donors
#
# class: SpecimenTag
# fields: id,name,description
# associations: specimens
# table: specimen_tags
#
# class: SubImageAnnotationTag
# fields: id,name
# associations: sub_image_annotations
# table: sub_image_annotation_tags
#
# class: DataPoint
# fields: id,gene_id,product_id,structure_id,data_point_type_id,weight,failed,treatment_id,failed_facet
# associations: gene,product,structure,treatment,data_point_type,donors
# table: data_points
#
# class: DevelopmentalStage
# fields: id,name,order,human_cortical_development_facet
# associations: ages
# table: developmental_stages
#
# class: StructureCenter
# fields: id,structure_id,x,y,z,reference_space_id
# associations: structure,reference_space
# table: structure_centers
#
# class: ApiGbmSubBlockDetail
# fields: donor_id,tumor_name,molecular_subtype,extent_of_resection,surgery,mgmt_methylation,survival_days,egfr_amplification,initial_kps,age_in_years,sub_block_id,sub_block_name,study_name,specimen_page_link,data_set_id,normalized_area_le,normalized_area_lehbv,normalized_area_it,normalized_area_ithbv,normalized_area_ct,normalized_area_ctpnz,normalized_area_ctpnn,normalized_area_ctpan,normalized_area_cthbv,normalized_area_ctmvp,normalized_area_ctne
# associations: donor,sub_block
# table: api_gbm_sub_block_details
#
# class: CellRoi
# fields: id,cell_specimen_id,ophys_experiment_id,x,y,width,height,max_correction_up,max_correction_down,max_correction_right,max_correction_left,mask_matrix
# associations: ophys_experiment,cell_specimen,cell_roi_analysis_runs
# table: cell_rois
#
# class: StereotaxicInjectionCoordinate
# fields: id,coordinates_ap,coordinates_ml,coordinates_dv,angle,registration_point,stereotaxic_injection_id
# associations: stereotaxic_injection
# table: stereotaxic_injection_coordinates
#
# class: ApiCamExperimentContainerMetric
# fields: experiment_container_id,specimen_id,area,tld1_id,tld1_name,tld2_id,tld2_name,tlr1_id,tlr1_name,imaging_depth,failed_experiment_container,projection_a,projection_b,projection_c,preferred_direction_small,preferred_direction_large,orientation_selectivity_dg_small,orientation_selectivity_dg_large,direction_selectivity_small,direction_selectivity_large,preferred_temporal_frequency_small,preferred_temporal_frequency_large,correlation_a_large,correlation_a_small,representational_similarity_dg_large,representational_similarity_dg_small,running_speed_a_large,running_speed_a_small,preferred_orientation_small,preferred_orientation_large,preferred_spatial_frequency_small,preferred_spatial_frequency_large,orientation_selectivity_sg_small,orientation_selectivity_sg_large,time_to_peak_sg_small,time_to_peak_ns_small,time_to_peak_ns_large,representational_similarity_sg_large,representational_similarity_sg_small,time_to_peak_sg_large,representational_similarity_ns_large,representational_similarity_ns_small,correlation_b_large,correlation_b_small,running_speed_b_large,running_speed_b_small,population_receptive_field_large,population_receptive_field_small,running_speed_c_large,running_speed_c_small,eye_position_a_small,eye_position_a_large,eye_position_b_small,eye_position_b_large,eye_position_c_small,eye_position_c_large,mean_running_speed_a,mean_running_speed_b,mean_running_speed_c,donor_full_genotype
# associations:
# table: api_cam_experiment_container_metrics
#
# class: GraphicGroupLabel
# fields: id,name,color
# associations: groups,graphic_objects,atlases,atlas_infos,polygon_spatial_mappings
# table: graphic_group_labels
#
# class: AnnotationStructure
# fields: id,specimen_id,structure_id,name,acronym,tags
# associations: structure,specimen
# table: annotation_structures
#
# class: FineStructureSearch
# fields: id,section_data_set_id,structure_id,gene_rank
# associations: structure,section_data_set
# table: fine_structure_searches
#
# class: Organism
# fields: id,name,ncbitaxonomyid,tags
# associations: ontologies,ages,chromosomes,donors,genes,reference_genomes,reference_spaces
# table: organisms
#
# class: Product
# fields: id,name,abbreviation,resource,description,tags,species,product_name_facet,species_name_facet
# associations: ontologies,data_sets,donors,genes,probes,reference_spaces,data_points,documents,specimens
# table: products
#
# class: WellKnownFileType
# fields: id,name
# associations: well_known_files
# table: well_known_file_types
#
# class: AtlasContour
# fields: id,atlas_id,section_image_id,structure_id,graphic_group_id,contour_id,svg_transformation_matrix,svg_transformation_string,x,y,width,height,max_zoom,file_path,specimen_order,section_number,contour_order,contour_path
# associations: atlas,section_image,structure,group
# table: atlas_contours
#
# class: DatabaseStatus
# fields: id,database_updated,created_at
# associations:
# table: database_statuses
#
# class: GraphicTransformation
# fields: id,type,order,sx,rx,ry,sy,tx,ty,a,graphic_object_id
# associations: graphic_object
# table: graphic_transformations
#
# class: Scale
# fields: id,type,order,sx,rx,ry,sy,tx,ty,a,graphic_object_id
# associations: graphic_object
# table: graphic_transformations
#
# class: GeneLookup
# fields: id,term,termtype,gene_id,product_id
# associations: gene,product
# table: gene_lookups
#
# class: Equalization
# fields: id,red_lower,red_upper,green_lower,green_upper,blue_lower,blue_upper,red_mean,red_std_dev,green_mean,green_std_dev,blue_mean,blue_std_dev,section_data_set_id
# associations: section_data_set
# table: equalizations
#
# class: IshCanonicalBlock
# fields: id,product_id,specimen_type_id,x,y,z,size_x,size_y,size_z,color_hex_triplet,atlas_id,sub_image_id,sub_image_x,sub_image_y
# associations: product,specimen_type,atlas,sub_image
# table: ish_canonical_blocks
#
# class: GeneHistory
# fields: id,taxonomy_id,entrez_id,discontinued_entrez_id,discontinued_symbol,discontinued_date
# associations:
# table: gene_histories
#
# class: GeneClassificationCount
# fields: id,product_id,gene_classification_id,distinct_gene_count
# associations: gene_classification,genes,product
# table: gene_classification_counts
#
# class: MedicalCondition
# fields: id,condition_value
# associations: donors
# table: medical_conditions
#
# class: DataPointType
# fields: id,name,tags,description
# associations: data_points
# table: data_point_types
#
# class: ApiTbiDonorMetric
# fields: donor_id,donor_name,structure_id,structure_acronym,ihc_a_syn,ihc_at8_ffpe,ihc_tau2_ffpe,ihc_at8,ihc_a_beta_ffpe,ihc_ptdp_43_ffpe,ihc_a_beta,ihc_iba1_ffpe,ihc_gfap_ffpe,ptau_ng_per_mg,vegf_pg_per_mg,ab42_over_ab40_ratio,tnf_a_pg_per_mg,tau_ng_per_mg,il_10_pg_per_mg,isoprostane_pg_per_mg,il_6_pg_per_mg,il_1b_pg_per_mg,ptau_over_tau_ratio,il_4_pg_per_mg,rantes_pg_per_mg,ab40_pg_per_mg,a_syn_pg_per_mg,ifn_g_pg_per_mg,mcp_1_pg_per_mg,bdnf_pg_per_mg,mip_1a_pg_per_mg,il_7_pg_per_mg,ab42_pg_per_mg
# associations: donor,structure
# table: api_tbi_donor_metrics
#
# class: NeuroNameStructureSynonym
# fields: id,name,language,organism,concept_id,default_name,old_concept_type,old_nn_id
# associations:
# table: neuro_name_structure_synonyms
#
# class: NeuroNameStructure
# fields: id,name,latin_name,acronym,v_s,p_s,parent_id,url,old_concept_type,old_nn_id
# associations: structures,neuro_name_structure_synonyms
# table: neuro_name_structures
#
# class: Hemisphere
# fields: id,name,symbol
# associations: structures
# table: hemispheres
#
# class: AgeGroup
# fields: id,name,order,age_group_facet
# associations: ages
# table: age_groups
#
# class: EphysSweep
# fields: id,stimulus_name,stimulus_description,stimulus_relative_amplitude,stimulus_absolute_amplitude,stimulus_duration,stimulus_units,sweep_number,leak_pa,pre_noise_rms_mv,post_noise_rms_mv,slow_noise_rms_mv,pre_vm_mv,post_vm_mv,vm_delta_mv,slow_vm_mv,num_spikes,specimen_id,bridge_balance_mohm,stimulus_start_time,stimulus_interval,peak_deflection
# associations: specimen,well_known_files
# table: ephys_sweeps
#
# class: StructureBoundingBox
# fields: id,atlas_id,structure_id,section_data_set_id,section_image_id,section_number,x,y,width,height
# associations: atlas,structure,section_data_set,section_image
# table: structure_bounding_boxes
#
# class: Condition
# fields: id,name,description
# associations: donor_condition_values,donors
# table: conditions
#
# class: NeuronalModel
# fields: id,name,neuronal_model_template_id,specimen_id
# associations: neuronal_model_template,neuronal_model_runs,specimen,well_known_files
# table: neuronal_models
#
# class: Orientation
# fields: id,name
# associations: probes
# table: orientations
#
# class: GeneAlias
# fields: id,gene_id,acronym
# associations: gene
# table: gene_aliases
#
# class: Sample
# fields: id,tissue_sample_data_set_id,structure_id,rna_integrity_number
# associations: microarray_data_set,tissue_sample_data_set,structure,microarray_slides,rnaseq_profiles
# table: samples
#
# class: ImageStructureData
# fields: id,data_set_id,structure_id,hemisphere_id,data
# associations: data_set,structure,hemisphere
# table: image_structure_data
#
# class: IsiExperiment
# fields: id,name,specimen_id,storage_directory,date_of_acquisition
# associations: specimen,experiment_container,isi_experiment_images,well_known_files,annotated_regions,donor
# table: isi_experiments
#
# class: AtlasInfo
# fields: id,organism_name,plane_of_section_name,age_name,atlas_id,structure_graph_id,specimen_id,plane_of_section_id,age_id,atlas_title,xyz_sort,treatment_id,graphic_group_label_id
# associations: atlas,structure_graph,specimen,plane_of_section,age,treatment,graphic_group_label
# table: atlas_infos
#
# class: CellReporter
# fields: id,name
# associations: specimens
# table: cell_reporters
#
# class: NeuronalModelTemplate
# fields: id,name,description
# associations: neuronal_models,well_known_files
# table: neuronal_model_templates
#
# class: GeneAssociation
# fields: id,gene_feature_id,gene_feature_type,gene_id,gene_association_source_id
# associations: gene,gene_association_source
# table: gene_associations
#
# class: ApiGbmGeneExpressionDetail
# fields: donor_id,tumor_name,molecular_subtype,extent_of_resection,surgery,mgmt_methylation,survival_days,egfr_amplification,initial_kps,age_in_years,sub_block_id,sub_block_name,study_name,specimen_page_link,data_set_id,gene_id,gene_symbol,entrez_id,expression_energy_le,expression_energy_lehbv,expression_energy_it,expression_energy_ithbv,expression_energy_ct,expression_energy_ctpnz,expression_energy_ctpnn,expression_energy_ctpan,expression_energy_cthbv,expression_energy_ctmvp,expression_energy_ctne
# associations: donor,sub_block,data_set,gene
# table: api_gbm_gene_expression_details
#
# class: GenomeLocus
# fields: id,start_pos,stop_pos,chromosome_id,reference_genome_id,parent_locus_id,genomic_feature_id,genomic_feature_type
# associations: chromosome,reference_genome,parent_genome_locus,child_genome_loci
# table: genome_loci
#
# class: Chromosome
# fields: id,name,organism_id
# associations: organism,genes,genome_locuses
# table: chromosomes
#
# class: WellKnownFile
# fields: id,path,attachable_id,attachable_type,well_known_file_type_id,download_link
# associations: well_known_file_type
# table: well_known_files
#
# class: ExperimentContainer
# fields: id,isi_experiment_id,targeted_structure_id,specimen_id,imaging_depth,failed,weight,failed_facet
# associations: ophys_experiments,isi_experiment,specimen,targeted_structure
# table: experiment_containers
#
# class: Alignment3d
# fields: id,aligned_type,aligned_id,tvr_00,tvr_01,tvr_02,tvr_03,tvr_04,tvr_05,tvr_06,tvr_07,tvr_08,tvr_09,tvr_10,tvr_11,trv_00,trv_01,trv_02,trv_03,trv_04,trv_05,trv_06,trv_07,trv_08,trv_09,trv_10,trv_11
# associations:
# table: alignment3ds
#
# class: AffymetrixMacaqueProbeset
# fields: id,displayable_id_from_affymetrix
# associations: gene_association,gene_associations
# table: affymetrix_macaque_probesets
#
# class: DonorConditionValue
# fields: id,condition_id,donor_id,value
# associations: donor,condition
# table: donor_condition_values
#
# class: Specimen
# fields: id,donor_id,name,tissue_ph,rna_integrity_number,hemisphere,structure_id,parent_id,parent_x_coord,parent_y_coord,parent_z_coord,external_specimen_name,specimen_id_path,ephys_result_id,is_ish,sphinx_id,weight,failed_facet,is_cell_specimen,treatment_id,data,cell_reporter_id,cell_prep_sample_id
# associations: parent,children,ancestor_hierarchies,self_and_ancestors,descendant_hierarchies,self_and_descendants,data_sets,specimen_images,projection_images,well_known_files,stereotaxic_injections,injections,specimen_types,donor,structure,alignment3d,atlases,atlas_infos,polygon_spatial_mappings,ephys_result,ephys_sweeps,ephys_features,neuron_reconstructions,neuronal_models,cell_soma_locations,specimen_tags,products,treatment,cell_reporter,cell_prep_sample,cell_prep_samples,annotation_structures,hotspot_structures
# table: specimens
#
# class: SpecimenHierarchy
# fields: ancestor_id,descendant_id,generations
# associations: ancestor,descendant
# table: specimen_hierarchies
#
# class: StructureUnionize
# fields: id,section_data_set_id,structure_id,sum_pixels,sum_expressing_pixels,sum_pixel_intensity,sum_expressing_pixel_intensity,expression_density,expression_energy,voxel_energy_mean,voxel_energy_cv
# associations: section_data_set,structure
# table: structure_unionizes
#
# class: StructureGraph
# fields: id,name,root_structure_id,ontology_id
# associations: root_structure,ontology,atlases,atlas_infos,ontology_nodes
# table: structure_graphs
#
# class: Document
# fields: id,heading,title,description,url,tags,product_id,weight,failed,failed_facet,treatment_id,document_type
# associations: product,treatment
# table: documents
#
# class: AffymetrixProbeset
# fields: id,displayable_id_from_affymetrix
# associations: gene_association,genome_locus
# table: affymetrix_probesets
#
# class: WarehouseTable
# fields: id,name,average_new_records,new_records,number_of_records,number_of_runs
# associations:
# table: warehouse_tables
#
# class: CellSomaLocation
# fields: id,x,y,z,normalized_depth,specimen_id,reference_space_id
# associations: specimen,reference_space
# table: cell_soma_locations
#
# class: AnnotatedRegion
# fields: id,x,y,width,height,attachable_type,attachable_id,structure_id,sign_positive,pixel_centroid_x,pixel_centroid_y,reticle_centroid_x,reticle_centroid_y,min_altitude,max_altitude,range_altitude,bias_altitude,min_azimuth,max_azimuth,range_azimuth,bias_azimuth,eccentricity_at_centroid,area,mask_matrix
# associations: structure
# table: annotated_regions
#
# class: DiseaseCategory
# fields: id,condition_value,disease_categories_facet
# associations: donors
# table: disease_categories
#
# class: Ontology
# fields: id,name,organism_id,has_atlas,description,abbreviation
# associations: structure_graphs,structure_lookups,structures,organism,products
# table: ontologies
#
# class: Alignment2d
# fields: id,tvs_00,tvs_01,tvs_02,tvs_03,tvs_04,tvs_05,tsv_00,tsv_01,tsv_02,tsv_03,tsv_04,tsv_05,section_image_id
# associations: section_image
# table: alignment2ds
#
# class: ApiGbmTumorDetail
# fields: donor_id,tumor_name,molecular_subtype,extent_of_resection,surgery,mgmt_methylation,survival_days,egfr_amplification,initial_kps,age_in_years
# associations: donor
# table: api_gbm_tumor_details
#
# class: StereotaxicInjection
# fields: id,injection_quality,days_post_injection,injection_method,specimen_id,targeted_injection_structure_id,primary_injection_structure_id,age_id,sphinx_id
# associations: specimen,structures,age,primary_injection_structure,targeted_injection_structure,stereotaxic_injection_coordinates,stereotaxic_injection_materials
# table: stereotaxic_injections
#
# class: ReferenceSpace
# fields: id,organism_id,age_id,anatomy,name,storage_directory
# associations: organism,age,products,well_known_files,atlases,data_sets,structure_centers,cell_soma_locations
# table: reference_spaces
#
# class: ManualAnnotation
# fields: id,structure_id,section_data_set_id,annotation_plan_name,intensity_call,density_call,pattern_call,mixed_population_call,comment
# associations: structure,section_data_set
# table: manual_annotations
#
# class: ApiCellTypesSpecimenDetail
# fields: line_name,specimen_id,specimen_name,specimen_hemisphere,structure_id,structure_name,structure_acronym,structure_parent_id,structure_parent_acronym,structure_layer,nr_max_euclidean_distance,nr_number_stems,nr_number_bifurcations,nr_average_contraction,nr_average_parent_daughter_ratio,nrwkf_id,erwkf_id,ef_upstroke_downstroke_ratio_short_square,ef_fast_trough_v_long_square,ef_f_i_curve_slope,ef_threshold_i_long_square,ef_peak_t_ramp,ef_vrest,si_height,si_width,si_path,csl_x,csl_y,csl_z,csl_normalized_depth,m_glif,m_biophys,tag_apical,tag_dendrite_type
# associations: specimen,structure,structure_parent
# table: api_cell_types_specimen_details
#
# class: ReferenceGenome
# fields: id,name,build,organism_id,genomic_reference_update_id
# associations: organism,genome_locuses,genomic_reference_update,genes,genomic_objects
# table: reference_genomes
#
# class: NeuronReconstruction
# fields: id,scale_factor_x,scale_factor_y,scale_factor_z,number_nodes,soma_surface,number_stems,number_bifurcations,number_branches,number_tips,overall_width,overall_height,overall_depth,average_diameter,total_length,total_surface,total_volume,max_euclidean_distance,max_path_distance,max_branch_order,average_contraction,average_fragmentation,average_parent_daughter_ratio,average_bifurcation_angle_local,average_bifurcation_angle_remote,hausdorff_dimension,specimen_id,tags
# associations: specimen,well_known_files
# table: neuron_reconstructions
