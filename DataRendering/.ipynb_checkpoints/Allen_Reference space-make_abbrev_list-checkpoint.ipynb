# %%
from allensdk.api.queries.ontologies_api import OntologiesApi
from allensdk.core.structure_tree import StructureTree
from allensdk.api.queries.mouse_connectivity_api import MouseConnectivityApi
from allensdk.config.manifest import Manifest
from allensdk.core.reference_space import ReferenceSpace
import os
import nrrd
import functools
import numpy as np
import itertools
import math

# Input directory of where the ID file is stored
ID_directory='D:\\Data\\DevelopingAllenMouseAPI-master\\Git\\Data'
# Input file name
ID_file='SpC_descendantID_clean.csv'

import csv
f=open(os.path.join(ID_directory, ID_file), "r")
reader=csv.reader(f,delimiter=',')
ID_need=[]
for row in reader:
    ID=row[0]
    ID_need.append(ID)
ID_need=[int(float(i)) for i in ID_need]

print('A total of %d brain regions inputted'%(len(ID_need)))


oapi = OntologiesApi()
structure_graph = oapi.get_structures_with_sets([17])  # 1 is the id of the adult mouse structure graph

# This removes some unused fields returned by the query
structure_graph = StructureTree.clean_structures(structure_graph)

tree = StructureTree(structure_graph)
# Out:
# A total of 592 brain regions inputted

# %%
ID_need
# Out:
# [15570,
#  15579,
#  15585,
#  15588,
#  15590,
#  15593,
#  15597,
#  15600,
#  15602,
#  15608,
#  15610,
#  15614,
#  15616,
#  15617,
#  15620,
#  15623,
#  15625,
#  15627,
#  15629,
#  15632,
#  15654,
#  15656,
#  15659,
#  15663,
#  15666,
#  15668,
#  15670,
#  15673,
#  15680,
#  15685,
#  15687,
#  15693,
#  15699,
#  15703,
#  15708,
#  15710,
#  15713,
#  15718,
#  15720,
#  15724,
#  15725,
#  15740,
#  15742,
#  15748,
#  15750,
#  15754,
#  15756,
#  15759,
#  15762,
#  15766,
#  15768,
#  15770,
#  15773,
#  15775,
#  15777,
#  15781,
#  15783,
#  15786,
#  15788,
#  15792,
#  15795,
#  15798,
#  15800,
#  15803,
#  15806,
#  15810,
#  15812,
#  15814,
#  15816,
#  15820,
#  15822,
#  15828,
#  15831,
#  15835,
#  15837,
#  15842,
#  15845,
#  15852,
#  15854,
#  15856,
#  15861,
#  15869,
#  15871,
#  15873,
#  15877,
#  15906,
#  15908,
#  15911,
#  15914,
#  15918,
#  15920,
#  15921,
#  15922,
#  15929,
#  15931,
#  15932,
#  15936,
#  15941,
#  15943,
#  15946,
#  15949,
#  15970,
#  15972,
#  15973,
#  15974,
#  15980,
#  15982,
#  15983,
#  15985,
#  16199,
#  16201,
#  16202,
#  16203,
#  16206,
#  16208,
#  16209,
#  16210,
#  16212,
#  16214,
#  16216,
#  16225,
#  16231,
#  16236,
#  16239,
#  16244,
#  16253,
#  16264,
#  16280,
#  16290,
#  16296,
#  16297,
#  16306,
#  16311,
#  16313,
#  16316,
#  16318,
#  16319,
#  16321,
#  16324,
#  16326,
#  16328,
#  16330,
#  16334,
#  16336,
#  16338,
#  16340,
#  16344,
#  16346,
#  16348,
#  16350,
#  16353,
#  16354,
#  16356,
#  16358,
#  16364,
#  16369,
#  16371,
#  16372,
#  16373,
#  16377,
#  16382,
#  16385,
#  16387,
#  16390,
#  16393,
#  16397,
#  16399,
#  16409,
#  16433,
#  16440,
#  16443,
#  16450,
#  16456,
#  16458,
#  16461,
#  16470,
#  16472,
#  16474,
#  16479,
#  16481,
#  16483,
#  16487,
#  16488,
#  111220562,
#  111220566,
#  111220568,
#  111220570,
#  111220576,
#  111220584,
#  111220588,
#  111220612,
#  111220624,
#  111220626,
#  111220628,
#  111220632,
#  111220634,
#  111220636,
#  111220638,
#  111220640,
#  111220650,
#  111220652,
#  111220654,
#  111220656,
#  111220658,
#  111220660,
#  111220664,
#  111220666,
#  111220668,
#  111220670,
#  111220672,
#  111220682,
#  111220684,
#  111220686,
#  111220688,
#  111220690,
#  111220692,
#  111220696,
#  111220698,
#  111220702,
#  111220704,
#  111220714,
#  111220716,
#  111220720,
#  111220722,
#  111220724,
#  111220728,
#  111220730,
#  111220734,
#  111220736,
#  111220746,
#  111220748,
#  111220752,
#  111220754,
#  111220756,
#  111220760,
#  111220762,
#  111220764,
#  111220766,
#  111220768,
#  111220778,
#  111220784,
#  111220786,
#  111220788,
#  111220790,
#  111220792,
#  111220794,
#  111220796,
#  111220798,
#  111220800,
#  111220816,
#  111220818,
#  111220820,
#  111220824,
#  111220826,
#  111220828,
#  111220830,
#  111220832,
#  111220842,
#  111220844,
#  111220846,
#  111220848,
#  111220850,
#  111220852,
#  111220854,
#  111220856,
#  111220858,
#  111220868,
#  111220870,
#  111220872,
#  111220874,
#  111220876,
#  111220878,
#  111220880,
#  111220882,
#  111220884,
#  111220894,
#  111220896,
#  111220898,
#  111220900,
#  111220902,
#  111220904,
#  111220906,
#  111220908,
#  111220910,
#  111220922,
#  111220924,
#  111220926,
#  111220928,
#  111220930,
#  111220932,
#  111220934,
#  111220936,
#  112892285,
#  112892293,
#  112892303,
#  112892305,
#  112892307,
#  112892309,
#  112892311,
#  112892313,
#  112892317,
#  112892319,
#  112892321,
#  112892327,
#  112892329,
#  112892331,
#  112892353,
#  112892359,
#  112892361,
#  112892363,
#  112892367,
#  112892369,
#  112892371,
#  112892413,
#  112892415,
#  112892419,
#  112892425,
#  112892427,
#  112892429,
#  112892435,
#  112892437,
#  112892447,
#  114403711,
#  114403727]

# %%
tree.get_structures_by_name('superficial stratum of the SpAL')
# Out:
# [{u'acronym': u'SpALs',
#   u'color_hex_triplet': u'EBE3D5',
#   u'graph_id': 17,
#   u'graph_order': 2422,
#   u'id': 17674,
#   u'name': u'superficial stratum of the SpAL',
#   u'structure_id_path': [15564, 15565, 17651, 17653, 17666, 17669, 17674],
#   'structure_set_ids': []}]

# %%
name_map = tree.get_name_map()
name_map[17156]

# %%
# make a list of abbreviations (for trial)
acronym_need=[]
acronym_map = tree.value_map(lambda x: x['id'], lambda y: y['acronym'])
#print( acronym_map[385] )


index=0
for i in ID_need:
    acronym_need=acronym_need+[acronym_map[ID_need[index]]]
    index=index+1

# %%
# save the list of structure ID
np.savetxt("ID.csv",ID_need,fmt='%.20d',delimiter=",")

# %%
# save the list of region acronyms
np.savetxt("GridAnnoAcronym_E13pt5.csv",acronym_need,fmt='%.20s',delimiter=",")

# %%
acronym_need[352]

# %%
tree.get_structures_by_acronym

# %%
tree.get_structures_by_acronym('MTN')

# %%
# get a dictionary mapping structure ids to names

name_map = tree.get_name_map()
name_map[1009]

# %%
name_map[997]

# %%
tree.get_structures_by_name('root')

# %%
tree.get_structures_by_name('fiber tracts')

# %%
tree.get_structure_sets()
